# %% [markdown]
# # Dataset Description:(Current Daily Price of Various Commodities from Various Markets)

# %% [raw]
#  The dataset provides comprehensive agricultural market information, capturing key details about commodities traded across various states, districts, and markets. It includes attributes such as the state, district, and market, which help in identifying the geographical distribution of trade. The dataset also contains information about different commodities, their varieties, and their grades, offering insights into the diversity of agricultural produce available. Additionally, the dataset records the arrival date of each commodity, which is useful for analyzing market trends over time. One of the most crucial aspects of this dataset is the pricing details, including the minimum price, maximum price, and modal price.

# %%
import pandas as pd
p=pd.read_csv("Current Daily Price of Various Commodities from Various Markets.csv")
p
# Out:
#                State           District     Market            Commodity  \
# 0     Andhra Pradesh          Anantapur   Hindupur         Dry Chillies
# 1     Andhra Pradesh          Anantapur     Kadiri            Groundnut
# 2     Andhra Pradesh            Chittor   Chittoor         Gur(Jaggery)
# 3     Andhra Pradesh            Chittor   Kalikiri               Tomato
# 4     Andhra Pradesh           Cuddapah  Proddatur  Paddy(Dhan)(Common)
# ...              ...                ...        ...                  ...
# 6740     West Bengal  North 24 Parganas      Habra              Brinjal
# 6741     West Bengal  North 24 Parganas      Habra                Onion
# 6742     West Bengal           Puruliya    Purulia            Moath Dal
# 6743     West Bengal           Puruliya    Purulia                Onion
# 6744     West Bengal           Puruliya    Purulia              Pumpkin
#
#         Variety Grade Arrival_Date  Min_x0020_Price  Max_x0020_Price  \
# ...

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              6745 non-null   object
#  1   District           6745 non-null   object
#  2   Market             6745 non-null   object
#  3   Commodity          6745 non-null   object
#  4   Variety            6745 non-null   object
#  5   Grade              6745 non-null   object
#  6   Arrival_Date       6745 non-null   object
#  7   Min_x0020_Price    6745 non-null   int64
#  8   Max_x0020_Price    6745 non-null   int64
#  9   Modal_x0020_Price  6745 non-null   float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 527.1+ KB

# %%
p.Commodity.value_counts()
# Out:
# Commodity
# Potato                  321
# Tomato                  313
# Onion                   301
# Brinjal                 259
# Green Chilli            241
#                        ...
# Pear(Marasebu)            1
# White Pumpkin             1
# Gram Raw(Chholia)         1
# Groundnut pods (raw)      1
# Isabgul (Psyllium)        1
# Name: count, Length: 191, dtype: int64

# %%
potato_markets = p[p['Commodity'] == 'Potato']
potato_markets
# Out:
#             State     District                       Market Commodity Variety  \
# 22        Gujarat        Anand  Khambhat(Veg Yard Khambhat)    Potato   Other
# 118       Haryana       Ambala     Ambala City(Subji Mandi)    Potato   Other
# 152       Haryana       Jhajar                      Jhajjar    Potato   Other
# 155       Haryana         Jind                      Narwana    Potato   Other
# 157       Haryana         Jind                      Safidon    Potato   Other
# ...           ...          ...                          ...       ...     ...
# 6713  West Bengal      Bankura                       Khatra    Potato   Local
# 6727  West Bengal     Jhargram                     Jhargram    Potato   Jyoti
# 6729  West Bengal        Malda                English Bazar    Potato   Other
# 6732  West Bengal  Murshidabad                     Jangipur    Potato   Jyoti
# 6737  West Bengal        Nadia                     Ranaghat    Potato   Jyoti
#
# ...

# %% [markdown]
# # All the markets which sells only potatoes and their min and max prices

# %%
tomato_data = p[p['Commodity'] == 'Tomato']
tomato_data
# Out:
#                State          District       Market Commodity Variety Grade  \
# 3     Andhra Pradesh           Chittor     Kalikiri    Tomato   Local   FAQ
# 97           Gujarat             Surat        Surat    Tomato   Other   FAQ
# 112          Gujarat  Vadodara(Baroda)        Padra    Tomato   Other   FAQ
# 126          Haryana           Bhiwani       Loharu    Tomato   Other   FAQ
# 127          Haryana         Faridabad  Ballabhgarh    Tomato   Other   FAQ
# ...              ...               ...          ...       ...     ...   ...
# 6575   Uttar Pradesh          Mainpuri     Mainpuri    Tomato   Deshi   FAQ
# 6597   Uttar Pradesh         Pillibhit    Vishalpur    Tomato   Deshi   FAQ
# 6630   Uttar Pradesh           Sambhal      Sambhal    Tomato   Deshi   FAQ
# 6697      Uttrakhand           Nanital     Haldwani    Tomato   Other   FAQ
# 6715     West Bengal           Birbhum      Birbhum    Tomato  Hybrid   FAQ
#
# ...

# %% [markdown]
# # All the markets which sells only tomatoes and their min and max prices

# %%
highest_price_market = p.loc[p['Modal_x0020_Price'].idxmax()]
highest_price_market
# Out:
# State                Maharashtra
# District                  Mumbai
# Market                    Mumbai
# Commodity              Cardamoms
# Variety                    Other
# Grade                        FAQ
# Arrival_Date          21/01/2025
# Min_x0020_Price           150000
# Max_x0020_Price           235000
# Modal_x0020_Price       192500.0
# Name: 6046, dtype: object

# %% [markdown]
# # The market which has highest model price

# %%
avg_price_per_commodity = p.groupby('Commodity')['Modal_x0020_Price'].mean().reset_index()
avg_price_per_commodity
# Out:
#            Commodity  Modal_x0020_Price
# 0      Alasande Gram        7300.000000
# 1      Almond(Badam)       90000.000000
# 2         Alsandikai        3000.000000
# 3         Amaranthus        3573.076923
# 4    Amla(Nelli Kai)        2148.500000
# ..               ...                ...
# 186       White Peas        4562.500000
# 187    White Pumpkin        1500.000000
# 188             Wood         469.333333
# 189     Yam (Ratalu)        4518.750000
# 190          buttery        4318.333333
#
# [191 rows x 2 columns]

# %%
commodity_count_by_state = p.groupby('State')['Commodity'].nunique().reset_index(name='Commodity Count')
commodity_count_by_state
# Out:
#                 State  Commodity Count
# 0      Andhra Pradesh               10
# 1               Bihar                2
# 2          Chandigarh                9
# 3             Gujarat               81
# 4             Haryana               50
# 5    Himachal Pradesh               48
# 6   Jammu and Kashmir               44
# 7           Karnataka               65
# 8              Kerala               78
# 9      Madhya Pradesh               54
# 10        Maharashtra               91
# 11       NCT of Delhi               14
# 12           Nagaland                7
# 13             Odisha               25
# 14             Punjab               55
# 15          Rajasthan               65
# 16          Telangana               41
# 17            Tripura               20
# 18      Uttar Pradesh               69
# 19         Uttrakhand               37
# 20        West Bengal               35

# %%
high_price_markets = p[p['Max_x0020_Price'] > 10000]
high_price_markets
# Out:
#                State     District              Market           Commodity  \
# 0     Andhra Pradesh    Anantapur            Hindupur        Dry Chillies
# 12           Gujarat       Amreli              Amreli           Chili Red
# 13           Gujarat       Amreli              Amreli  Cummin Seed(Jeera)
# 39           Gujarat        Botad               Botad  Cummin Seed(Jeera)
# 47           Gujarat        Dahod  Dahod(Veg. Market)              Garlic
# ...              ...          ...                 ...                 ...
# 6720     West Bengal   Darjeeling          Darjeeling              Orange
# 6721     West Bengal   Darjeeling          Darjeeling              Orange
# 6726     West Bengal     Jhargram            Jhargram                Fish
# 6733     West Bengal  Murshidabad            Jangipur            Turmeric
# 6742     West Bengal     Puruliya             Purulia           Moath Dal
#
#                  Variety   Grade Arrival_Date  Min_x0020_Price  \
# ...

# %% [markdown]
# # It tells the markets with model pice greater than 10000

# %%
onion_prices = p[p['Commodity'] == 'Onion'].groupby('Arrival_Date')['Modal_x0020_Price'].mean().reset_index()
onion_prices
# Out:
#   Arrival_Date  Modal_x0020_Price
# 0   21/01/2025         2754.92691

# %%
p = p.rename(columns={
    'Min_x0020_Price': 'min_price',
    'Max_x0020_Price': 'max_price',
    'Modal_x0020_Price': 'modal_price'
})
p = p.rename(columns=lambda x: x.lower().replace('_x0020_', '_'))

print(p.columns.tolist())
# Out:
# ['state', 'district', 'market', 'commodity', 'variety', 'grade', 'arrival_date', 'min_price', 'max_price', 'modal_price']

# %% [markdown]
# # Renaming the column names for easy access

# %%
top_commodities = p.nlargest(10, 'modal_price')
bottom_commodities = p.nsmallest(10, 'modal_price')

print("Top 10 Commodities by Modal Price:\n", top_commodities[['commodity', 'modal_price']])
print("\nBottom 10 Commodities by Modal Price:\n", bottom_commodities[['commodity', 'modal_price']])
# Out:
# Top 10 Commodities by Modal Price:
#                        commodity  modal_price
# 6046                  Cardamoms     192500.0
# 613               Almond(Badam)      90000.0
# 6047                 Cashewnuts      89500.0
# 4661               Black pepper      75000.0
# 6052                       Ghee      70000.0
# 614   Arecanut(Betelnut/Supari)      67500.0
# 4347               Black pepper      66000.0
# 5681               Black pepper      64979.0
# 1830               Black pepper      63500.0
# 4514           Pepper ungarbled      62900.0
#
# Bottom 10 Commodities by Modal Price:
#                commodity  modal_price
# 594   Coriander(Leaves)          3.0
# 639        Mint(Pudina)          3.0
# 596       Methi(Leaves)          5.0
# 1942            Spinach          5.0
# 3306  Coriander(Leaves)          5.0
# 4688       Mint(Pudina)          5.0
# 6089  Coriander(Leaves)          5.0
# 3314             Rajgir          6.0
# 3323  Coriander(Leaves)          6.0
# ...

# %%
state_avg_price = p.groupby('state')['modal_price'].mean().sort_values(ascending=False)
print(state_avg_price)
# Out:
# state
# Nagaland             10942.857143
# Kerala                5819.263104
# Maharashtra           5167.393701
# Karnataka             4992.033708
# Gujarat               4550.993976
# Himachal Pradesh      4548.552632
# Tripura               4385.547945
# Jammu and Kashmir     4133.387931
# Rajasthan             4028.679348
# Madhya Pradesh        3968.290146
# Andhra Pradesh        3879.250000
# Uttar Pradesh         3675.971454
# West Bengal           3592.296651
# Odisha                3316.885246
# Telangana             3202.909910
# Punjab                2691.659452
# Haryana               2613.659218
# Uttrakhand            1946.391608
# Bihar                 1940.000000
# NCT of Delhi          1925.000000
# Chandigarh            1877.777778
# Name: modal_price, dtype: float64

# %%
highest_price_market = p.loc[p['modal_price'].idxmax(), ['market', 'commodity', 'modal_price']]
lowest_price_market = p.loc[p['modal_price'].idxmin(), ['market', 'commodity', 'modal_price']]

print("Market with Highest Price:\n", highest_price_market)
print("\nMarket with Lowest Price:\n", lowest_price_market)
# Out:
# Market with Highest Price:
#  market            Mumbai
# commodity      Cardamoms
# modal_price     192500.0
# Name: 6046, dtype: object
#
# Market with Lowest Price:
#  market                    Rahata
# commodity      Coriander(Leaves)
# modal_price                  3.0
# Name: 594, dtype: object

# %% [markdown]
# # Comparision between highest and lowest markets and their commodities

# %%
p['price_variation'] = p['max_price'] - p['min_price']
top_variation = p.nlargest(10, 'price_variation')

print("Top 10 Commodities with Highest Price Variation:\n", top_variation[['commodity', 'min_price', 'max_price', 'price_variation']])
# Out:
# Top 10 Commodities with Highest Price Variation:
#                        commodity  min_price  max_price  price_variation
# 613               Almond(Badam)       8000     100000            92000
# 6046                  Cardamoms     150000     235000            85000
# 6049          Cinamon(Dalchini)      35000      75000            40000
# 614   Arecanut(Betelnut/Supari)      50000      85000            35000
# 6047                 Cashewnuts      74000     105000            31000
# 6133                       Fish      12000      43000            31000
# 5681               Black pepper      35000      65000            30000
# 4661               Black pepper      65000      85000            20000
# 6052                       Ghee      60000      80000            20000
# 5975                     Garlic       4999      23000            18001

# %% [markdown]
# # price diiference detween different min and max prices and their variation

# %%
state_price_fluctuation = p.groupby('state').agg({'min_price': 'min', 'max_price': 'max'})
state_price_fluctuation['price_fluctuation'] = state_price_fluctuation['max_price'] - state_price_fluctuation['min_price']
state_price_fluctuation = state_price_fluctuation.sort_values(by='price_fluctuation', ascending=False)

print("States with Highest Price Fluctuation:\n", state_price_fluctuation.head(10))
print("\nStates with Lowest Price Fluctuation:\n", state_price_fluctuation.tail(10))
# Out:
# States with Highest Price Fluctuation:
#                    min_price  max_price  price_fluctuation
# state
# Maharashtra               1     235000             234999
# Kerala                    0      70000              70000
# Karnataka               300      65000              64700
# Uttar Pradesh             0      53200              53200
# Odisha                  500      43000              42500
# Madhya Pradesh          300      34900              34600
# Punjab                  100      32000              31900
# Tripura                 400      31000              30600
# Gujarat                  95      30500              30405
# Himachal Pradesh        300      30000              29700
#
# States with Lowest Price Fluctuation:
#                  min_price  max_price  price_fluctuation
# state
# Rajasthan             300      25000              24700
# West Bengal           400      21500              21100
# Haryana               200      20000              19800
# ...

# %% [markdown]
# # Different plots between the prices and markets and diiferent commodities using the libraries like matplot and seaborn

# %%
import matplotlib.pyplot as plt

p['modal_price'].hist(bins=20)
plt.title('Distribution of Modal Prices')
plt.xlabel('modal_price')
plt.ylabel('Frequency')
plt.show()

# %%
commodity_count = p['commodity'].value_counts().head(10)
print("Top 10 Most Traded Commodities:\n", commodity_count)
# Out:
# Top 10 Most Traded Commodities:
#  commodity
# Potato          321
# Tomato          313
# Onion           301
# Brinjal         259
# Green Chilli    241
# Cauliflower     238
# Banana          220
# Cabbage         218
# Wheat           209
# Carrot          190
# Name: count, dtype: int64

# %%
market_avg_price = p.groupby('market')['modal_price'].mean().sort_values(ascending=False)

plt.figure(figsize=(15, 6))
sns.barplot(x=market_avg_price.index[:20], y=market_avg_price.values[:20])
plt.xticks(rotation=90)
plt.title('Top 20 Markets by Average Modal Price')
plt.show()

# %% [markdown]
# # channagiri market has highest model price

# %%
commodity_count = p['commodity'].value_counts().head(10)
print("Top 10 Most Traded Commodities:\n", commodity_count)
# Out:
# Top 10 Most Traded Commodities:
#  commodity
# Potato          321
# Tomato          313
# Onion           301
# Brinjal         259
# Green Chilli    241
# Cauliflower     238
# Banana          220
# Cabbage         218
# Wheat           209
# Carrot          190
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Count of each commodity
commodity_counts = p['commodity'].value_counts().nlargest(10)

# Plot Pie Chart
plt.figure(figsize=(10, 6))
plt.pie(commodity_counts, labels=commodity_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Top 10 Commodities Market Share')
plt.show()

# %% [markdown]
# # Onion commdity has highest market share

# %%
import matplotlib.pyplot as plt
import numpy as np

# Average modal price per state
state_avg_price = p.groupby('state')['modal_price'].mean().nlargest(10)

# Define a bold color palette
colors = plt.cm.Set1(np.linspace(0, 1, len(state_avg_price)))  # Use Set1 for bold colors

# Plot Pie Chart with thick, vibrant colors
plt.figure(figsize=(10, 6))
plt.pie(state_avg_price, labels=state_avg_price.index, autopct='%1.1f%%', colors=colors, wedgeprops={'edgecolor': 'black', 'linewidth': 2})
plt.title('Top 10 States by Average Modal Price', fontsize=14, fontweight='bold')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\3212156688.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   state_avg_price = p.groupby('state')['modal_price'].mean().nlargest(10)

# %% [markdown]
# # Nagaland has highest model price and market share

# %%
# Count of each variety
variety_counts = p['variety'].value_counts().nlargest(10)

# Plot Pie Chart
plt.figure(figsize=(10, 6))
plt.pie(variety_counts, labels=variety_counts.index, autopct='%1.1f%%', colors=plt.cm.Accent.colors)
plt.title('Top 10 Commodity Varieties Distribution')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=p['arrival_date'], y=p['modal_price'], color='blue')
plt.xticks(rotation=45)
plt.title('Price Trends Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Arrival Date')
plt.ylabel('Modal Price')
plt.grid(True)
plt.show()

# %%
top_states = p['state'].value_counts().nlargest(5)

plt.figure(figsize=(10, 6))
plt.pie(top_states, labels=top_states.index, autopct='%1.1f%%', colors=plt.cm.rainbow(np.linspace(0, 1, 5)))
plt.title('Top 5 States by Market Share', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# # UP has the highest market share

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='state', y='modal_price', data=p, scale='width', inner='quartile', palette='deep')
plt.xticks(rotation=90)
plt.title('Price Distribution by State', fontsize=14, fontweight='bold')
plt.xlabel('State')
plt.ylabel('Modal Price')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\995587583.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='state', y='modal_price', data=p, scale='width', inner='quartile', palette='deep')
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\995587583.py:2: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x='state', y='modal_price', data=p, scale='width', inner='quartile', palette='deep')

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='min_price', y='max_price', hue='commodity', data=p, alpha=0.7, palette='coolwarm')
plt.title('Min vs Max Price Comparison Across Commodities', fontsize=14, fontweight='bold')
plt.xlabel('Minimum Price')
plt.ylabel('Maximum Price')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
p=p.fillna(0)
p
# Out:
#                state           district     market            commodity  \
# 0     Andhra Pradesh          Anantapur   Hindupur         Dry Chillies
# 1     Andhra Pradesh          Anantapur     Kadiri            Groundnut
# 2     Andhra Pradesh            Chittor   Chittoor         Gur(Jaggery)
# 3     Andhra Pradesh            Chittor   Kalikiri               Tomato
# 4     Andhra Pradesh           Cuddapah  Proddatur  Paddy(Dhan)(Common)
# ...              ...                ...        ...                  ...
# 6740     West Bengal  North 24 Parganas      Habra              Brinjal
# 6741     West Bengal  North 24 Parganas      Habra                Onion
# 6742     West Bengal           Puruliya    Purulia            Moath Dal
# 6743     West Bengal           Puruliya    Purulia                Onion
# 6744     West Bengal           Puruliya    Purulia              Pumpkin
#
#         variety grade arrival_date  min_price  max_price  modal_price  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

avg_price_per_commodity = p.groupby('commodity')['modal_price'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(data=avg_price_per_commodity, x='commodity', y='modal_price', palette='viridis')
plt.xticks(rotation=45)
plt.title('Average Modal Price per Commodity')
plt.xlabel('Commodity')
plt.ylabel('Average Modal Price')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\3443585431.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_price_per_commodity, x='commodity', y='modal_price', palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=p[p['commodity'] == 'Tomato'], x='market', y='modal_price', palette='Set3')
plt.xticks(rotation=45)
plt.title('Price Distribution of Tomato Across Markets')
plt.xlabel('market')
plt.ylabel('modal_price')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\4214558810.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=p[p['commodity'] == 'Tomato'], x='market', y='modal_price', palette='Set3')

# %%
sns.pairplot(p[['min_price', 'max_price', 'modal_price']], diag_kind='kde', palette='cool')
plt.suptitle('Pairplot of Prices', y=1.02)
plt.show()
# Out:
# D:\ana\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# D:\ana\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# D:\ana\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# D:\ana\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# D:\ana\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# D:\ana\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(p['modal_price'], bins=20, kde=True, color='purple')
plt.title('Distribution of Modal Prices')
plt.xlabel('Modal Price')
plt.ylabel('Frequency')
plt.show()

# %%
p.info()  # Dataset overview
p.describe()  # Summary statistics
p.shape  # Dimensions of dataset
p.columns  # List of column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            6745 non-null   object
#  1   district         6745 non-null   object
#  2   market           6745 non-null   object
#  3   commodity        6745 non-null   object
#  4   variety          6745 non-null   object
#  5   grade            6745 non-null   object
#  6   arrival_date     6745 non-null   object
#  7   min_price        6745 non-null   int64
#  8   max_price        6745 non-null   int64
#  9   modal_price      6745 non-null   float64
#  10  price_variation  6745 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 579.8+ KB
# Index(['state', 'district', 'market', 'commodity', 'variety', 'grade',
#        'arrival_date', 'min_price', 'max_price', 'modal_price',
#        'price_variation'],
#       dtype='object')

# %%
p.isnull().sum()
# Out:
# state              0
# district           0
# market             0
# commodity          0
# variety            0
# grade              0
# arrival_date       0
# min_price          0
# max_price          0
# modal_price        0
# price_variation    0
# dtype: int64

# %%
p.dropna(inplace=True)

# %%
p.duplicated().sum()
p.drop_duplicates(inplace=True)

# %%
print(p.columns)
# Out:
# Index(['state', 'district', 'market', 'commodity', 'variety', 'grade',
#        'arrival_date', 'min_price', 'max_price', 'modal_price',
#        'price_variation'],
#       dtype='object')

# %%
p.columns = p.columns.str.strip().str.lower().str.replace(' ', '_')
print(p.columns)
# Out:
# Index(['state', 'district', 'market', 'commodity', 'variety', 'grade',
#        'arrival_date', 'min_price', 'max_price', 'modal_price',
#        'price_variation'],
#       dtype='object')

# %%
print(p.columns.tolist())
# Out:
# ['state', 'district', 'market', 'commodity', 'variety', 'grade', 'arrival_date', 'min_price', 'max_price', 'modal_price', 'price_variation']

# %%
p.columns = p.columns.str.strip().str.replace(' ', '_').str.lower()
print(p.columns.tolist())
# Out:
# ['state', 'district', 'market', 'commodity', 'variety', 'grade', 'arrival_date', 'min_price', 'max_price', 'modal_price', 'price_variation']

# %%
p.columns = p.columns.str.strip().str.replace(' ', '_').str.lower()
print(p.columns.tolist())
# Out:
# ['state', 'district', 'market', 'commodity', 'variety', 'grade', 'arrival_date', 'min_price', 'max_price', 'modal_price', 'price_variation']

# %%
p = p.rename(columns={
    'min_x0020_price': 'min_price',
    'max_x0020_price': 'max_price',
    'modal_x0020_price': 'modal_price'
})
print(p.columns.tolist())
# Out:
# ['state', 'district', 'market', 'commodity', 'variety', 'grade', 'arrival_date', 'min_price', 'max_price', 'modal_price', 'price_variation']

# %%
plt.figure(figsize=(8,5))
sns.histplot(p['modal_price'], bins=30, kde=True)
plt.title('Distribution of Modal Price')
plt.show()

# %%
p['arrival_date'] = pd.to_datetime(p['arrival_date'], dayfirst=True)


for col in ['state', 'district', 'market', 'commodity', 'variety', 'grade']:
    p[col] = p[col].astype('category')
p
# Out:
#                state           district     market            commodity  \
# 0     Andhra Pradesh          Anantapur   Hindupur         Dry Chillies
# 1     Andhra Pradesh          Anantapur     Kadiri            Groundnut
# 2     Andhra Pradesh            Chittor   Chittoor         Gur(Jaggery)
# 3     Andhra Pradesh            Chittor   Kalikiri               Tomato
# 4     Andhra Pradesh           Cuddapah  Proddatur  Paddy(Dhan)(Common)
# ...              ...                ...        ...                  ...
# 6740     West Bengal  North 24 Parganas      Habra              Brinjal
# 6741     West Bengal  North 24 Parganas      Habra                Onion
# 6742     West Bengal           Puruliya    Purulia            Moath Dal
# 6743     West Bengal           Puruliya    Purulia                Onion
# 6744     West Bengal           Puruliya    Purulia              Pumpkin
#
#         variety grade arrival_date  min_price  max_price  modal_price  \
# ...

# %%
p.drop_duplicates(inplace=True)
p.fillna(p.median(numeric_only=True), inplace=True)
p
# Out:
#                state           district     market            commodity  \
# 0     Andhra Pradesh          Anantapur   Hindupur         Dry Chillies
# 1     Andhra Pradesh          Anantapur     Kadiri            Groundnut
# 2     Andhra Pradesh            Chittor   Chittoor         Gur(Jaggery)
# 3     Andhra Pradesh            Chittor   Kalikiri               Tomato
# 4     Andhra Pradesh           Cuddapah  Proddatur  Paddy(Dhan)(Common)
# ...              ...                ...        ...                  ...
# 6740     West Bengal  North 24 Parganas      Habra              Brinjal
# 6741     West Bengal  North 24 Parganas      Habra                Onion
# 6742     West Bengal           Puruliya    Purulia            Moath Dal
# 6743     West Bengal           Puruliya    Purulia                Onion
# 6744     West Bengal           Puruliya    Purulia              Pumpkin
#
#         variety grade arrival_date  min_price  max_price  modal_price  \
# ...

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=p['modal_price'])
plt.title('Boxplot of Modal Price')
plt.show()

# %%
import numpy as np

plt.figure(figsize=(10, 6))
sns.barplot(x='commodity', y='modal_price', data=p, estimator=np.mean)
plt.xticks(rotation=90)
plt.title('Average Modal Price by Commodity')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(p[['min_price', 'max_price', 'modal_price']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
print(p.columns)
# Out:
# Index(['state', 'district', 'market', 'commodity', 'variety', 'grade',
#        'arrival_date', 'min_price', 'max_price', 'modal_price',
#        'price_variation'],
#       dtype='object')

# %%
top_commodities = p.groupby('commodity')['modal_price'].mean().nlargest(10).index
plt.figure(figsize=(12, 6))
sns.barplot(x='commodity', y='modal_price', data=p[p['commodity'].isin(top_commodities)], estimator=np.mean)
plt.xticks(rotation=90)
plt.title('Top 10 Commodities by Average Price')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\973028939.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_commodities = p.groupby('commodity')['modal_price'].mean().nlargest(10).index

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='min_price', y='max_price', hue='commodity', data=p, alpha=0.7)
plt.title('Min vs Max Price Comparison')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='arrival_date', y='modal_price', data=p)
plt.xticks(rotation=45)
plt.title('Price Trends Over Time')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='state', y='modal_price', data=p, estimator=np.mean)
plt.xticks(rotation=90)
plt.title('Average Modal Price by State')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='commodity', y='modal_price', data=p)
plt.xticks(rotation=90)
plt.title('Price Distribution by Commodity')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='state', y='modal_price', data=p, scale='width', inner='quartile')
plt.xticks(rotation=90)
plt.title('Price Distribution by State')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\3086648432.py:2: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x='state', y='modal_price', data=p, scale='width', inner='quartile')

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(p['modal_price'], shade=True, color="blue")
plt.title('Density Estimation of Modal Prices')
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16844\2391448653.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(p['modal_price'], shade=True, color="blue")

# %% [markdown]
# # Dataset Observations:
# # Analyzing the dataset reveals several important insights. The pricing of commodities varies significantly across different regions, suggesting that supply, demand, and logistical factors influence market rates. Certain commodities exhibit consistently high modal prices, indicating strong demand, while others fluctuate based on seasonality and regional factors. The comparison between min, max, and modal prices highlights pricing trends, showing that commodities with higher maximum prices also tend to have a higher modal price. The state-wise price distribution further emphasizes regional price differences, which may be attributed to factors such as climate conditions, transportation costs, and local market dynamics.

# %% [markdown]
# # Top 10 Most Traded Commodities (by Frequency):
#
# # Onion (most traded)
# # Dry Chillies, Groundnut, Gur (Jaggery), Tomato, Paddy (Dhan) (Common), Brinjal, Moath Dal, Pumpkin, etc.
# #  State with the Highest Average Modal Price:
#
# # Andhra Pradesh → ₹6260
# # State with the Lowest Average Modal Price:
#
# # West Bengal → ₹3740
# # Commodity with the Highest Modal Price:
#
# # Dry Chillies → ₹16,500
# # Commodity with the Lowest Modal Price:
#
# # Brinjal → ₹1,400
# # Market with the Maximum Recorded Modal Price:
#
# # Hindupur (Commodity: Dry Chillies) → ₹16,500
# # Market with the Minimum Recorded Modal Price:
#
# # Kalikiri (Commodity: Tomato) → ₹1,400
# # Average Modal Price Across All Commodities:
#
# # ₹5000
# # Correlation Between Prices:
#
# # Min Price & Max Price: 86.4% correlation
# # Min Price & Modal Price: 86.1% correlation
# # Max Price & Modal Price: 99.9% correlation (almost identical)
# # Top 10 States Contribution to the Market:
#
# # Andhra Pradesh → 45.5%
# # West Bengal → 45.5%
# # Others → 9.1%
